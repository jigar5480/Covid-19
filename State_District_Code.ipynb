# %% [markdown]
# # describing structure

# %%
import requests
import pandas as pd
x = requests.get('https://data.covid19india.org/v4/min/data.min.json')
df=pd.DataFrame(x.json()).transpose()
df
# Out:
#                                                 delta             delta21_14  \
# AN  {'tested': 1376, 'vaccinated1': 3, 'vaccinated...       {'confirmed': 9}
# AP  {'confirmed': 385, 'deceased': 4, 'recovered':...    {'confirmed': 3220}
# AR  {'confirmed': 1, 'recovered': 9, 'tested': 334...      {'confirmed': 87}
# AS  {'confirmed': 212, 'deceased': 1, 'recovered':...    {'confirmed': 1499}
# BR  {'confirmed': 8, 'recovered': 9, 'tested': 226...      {'confirmed': 30}
# CH  {'confirmed': 5, 'recovered': 3, 'tested': 140...      {'confirmed': 23}
# CT  {'confirmed': 32, 'deceased': 1, 'recovered': ...     {'confirmed': 124}
# DL  {'confirmed': 45, 'recovered': 46, 'tested': 5...     {'confirmed': 195}
# DN  {'recovered': 1, 'vaccinated1': 3, 'vaccinated...       {'confirmed': 4}
# GA  {'confirmed': 23, 'recovered': 53, 'tested': 2...     {'confirmed': 409}
# GJ  {'confirmed': 20, 'recovered': 23, 'tested': 3...     {'confirmed': 149}
# HP  {'confirmed': 85, 'deceased': 1, 'recovered': ...     {'confirmed': 958}
# HR  {'confirmed': 11, 'recovered': 10, 'tested': 2...      {'confirmed': 83}
# JH  {'confirmed': 10, 'recovered': 8, 'tested': 31...      {'confirmed': 78}
# JK  {'confirmed': 95, 'recovered': 79, 'tested': 3...     {'confirmed': 529}
# KA  {'confirmed': 292, 'deceased': 11, 'recovered'...    {'confirmed': 2432}
# KL  {'confirmed': 7167, 'deceased': 167, 'recovere...   {'confirmed': 59521}
# LA  {'confirmed': 11, 'recovered': 9, 'tested': 38...      {'confirmed': 26}
# LD                   {'tested': 31, 'vaccinated2': 4}                    NaN
# MH  {'confirmed': 1172, 'deceased': 20, 'recovered...   {'confirmed': 13825}
# ML  {'confirmed': 22, 'deceased': 1, 'recovered': ...     {'confirmed': 530}
# MN  {'confirmed': 63, 'deceased': 1, 'recovered': ...     {'confirmed': 734}
# MP  {'confirmed': 16, 'recovered': 8, 'tested': 55...      {'confirmed': 63}
# MZ  {'confirmed': 579, 'deceased': 2, 'recovered':...    {'confirmed': 6770}
# NL  {'confirmed': 11, 'deceased': 1, 'other': 1, '...     {'confirmed': 162}
# OR  {'confirmed': 488, 'deceased': 4, 'recovered':...    {'confirmed': 3381}
# PB  {'confirmed': 26, 'deceased': 1, 'recovered': ...     {'confirmed': 159}
# PY  {'confirmed': 38, 'recovered': 45, 'tested': 2...     {'confirmed': 343}
# RJ  {'confirmed': 2, 'recovered': 2, 'tested': 134...      {'confirmed': 31}
# SK  {'confirmed': 21, 'deceased': 1, 'recovered': ...      {'confirmed': 82}
# TG  {'confirmed': 121, 'deceased': 1, 'recovered':...    {'confirmed': 1068}
# TN  {'confirmed': 1009, 'deceased': 19, 'recovered...    {'confirmed': 8827}
# TR  {'confirmed': 12, 'recovered': 2, 'tested': 35...      {'confirmed': 49}
# TT  {'confirmed': 12907, 'deceased': 251, 'other':...  {'confirmed': 109755}
# UP  {'confirmed': 6, 'recovered': 6, 'tested': 161...      {'confirmed': 74}
# UT  {'confirmed': 5, 'recovered': 9, 'tested': 952...      {'confirmed': 88}
# WB  {'confirmed': 914, 'deceased': 15, 'recovered'...    {'confirmed': 4193}
#
#                                                delta7  \
# AN  {'confirmed': 3, 'recovered': 5, 'tested': 893...
# AP  {'confirmed': 2873, 'deceased': 30, 'recovered...
# AR  {'confirmed': 66, 'recovered': 97, 'tested': 4...
# AS  {'confirmed': 2056, 'deceased': 24, 'recovered...
# BR  {'confirmed': 40, 'recovered': 31, 'tested': 1...
# CH  {'confirmed': 28, 'recovered': 20, 'tested': 1...
# CT  {'confirmed': 205, 'deceased': 5, 'recovered':...
# DL  {'confirmed': 267, 'recovered': 239, 'tested':...
# DN  {'recovered': 2, 'vaccinated1': 2802, 'vaccina...
# GA  {'confirmed': 222, 'deceased': 6, 'recovered':...
# GJ  {'confirmed': 159, 'deceased': 2, 'recovered':...
# HP  {'confirmed': 1537, 'deceased': 20, 'other': -...
# HR  {'confirmed': 95, 'recovered': 87, 'tested': 1...
# JH  {'confirmed': 137, 'deceased': 3, 'recovered':...
# JK  {'confirmed': 611, 'deceased': 3, 'recovered':...
# KA  {'confirmed': 2347, 'deceased': 75, 'recovered...
# KL  {'confirmed': 53326, 'deceased': 3089, 'recove...
# LA  {'confirmed': 58, 'recovered': 28, 'tested': 2...
# LD  {'tested': 1625, 'vaccinated1': 69, 'vaccinate...
# MH  {'confirmed': 8117, 'deceased': 200, 'other': ...
# ML  {'confirmed': 256, 'deceased': 4, 'recovered':...
# MN  {'confirmed': 439, 'deceased': 10, 'recovered'...
# MP  {'confirmed': 105, 'deceased': 1, 'recovered':...
# MZ  {'confirmed': 4098, 'deceased': 21, 'recovered...
# NL  {'confirmed': 130, 'deceased': 6, 'other': 13,...
# OR  {'confirmed': 3046, 'deceased': 24, 'recovered...
# PB  {'confirmed': 192, 'deceased': 8, 'recovered':...
# PY  {'confirmed': 278, 'recovered': 315, 'tested':...
# RJ  {'confirmed': 27, 'recovered': 26, 'tested': 9...
# SK  {'confirmed': 79, 'deceased': 2, 'other': 6, '...
# TG  {'confirmed': 1189, 'deceased': 9, 'recovered'...
# TN  {'confirmed': 7407, 'deceased': 97, 'recovered...
# TR  {'confirmed': 87, 'recovered': 62, 'tested': 2...
# TT  {'confirmed': 96071, 'deceased': 3727, 'other'...
# UP  {'confirmed': 63, 'deceased': 1, 'recovered': ...
# UT  {'confirmed': 75, 'deceased': 1, 'other': 12, ...
# WB  {'confirmed': 6453, 'deceased': 86, 'recovered...
#
#                                             districts  \
# AN  {'Nicobars': {'delta7': {'vaccinated1': 62, 'v...
# AP  {'Anantapur': {'delta': {'confirmed': 4, 'reco...
# AR  {'Anjaw': {'delta7': {'vaccinated1': 45, 'vacc...
# AS  {'Baksa': {'delta': {'vaccinated1': 39, 'vacci...
# BR  {'Araria': {'delta': {'vaccinated1': 5177, 'va...
# CH  {'Chandigarh': {'delta': {'confirmed': 5, 'rec...
# CT  {'Balod': {'delta': {'vaccinated1': 523, 'vacc...
# DL  {'Delhi': {'delta': {'confirmed': 45, 'recover...
# DN  {'Dadra and Nagar Haveli': {'delta': {'vaccina...
# GA  {'North Goa': {'delta': {'vaccinated1': 1070, ...
# GJ  {'Ahmedabad': {'delta': {'confirmed': 4, 'reco...
# HP  {'Bilaspur': {'delta': {'confirmed': 11, 'reco...
# HR  {'Ambala': {'delta': {'vaccinated1': 100, 'vac...
# JH  {'Bokaro': {'delta': {'vaccinated1': 3236, 'va...
# JK  {'Anantnag': {'delta': {'confirmed': 2, 'recov...
# KA  {'Bagalkote': {'delta': {'vaccinated1': 823, '...
# KL  {'Alappuzha': {'delta': {'confirmed': 270, 'de...
# LA  {'Kargil': {'delta': {'vaccinated2': 3}, 'delt...
# LD  {'Lakshadweep': {'delta': {'tested': 31, 'vacc...
# MH  {'Ahmednagar': {'delta': {'confirmed': 138, 'd...
# ML  {'East Garo Hills': {'delta': {'recovered': 1}...
# MN  {'Bishnupur': {'delta7': {'vaccinated1': 685, ...
# MP  {'Agar Malwa': {'delta': {'vaccinated1': 12, '...
# MZ  {'Aizawl': {'delta': {'confirmed': 361, 'decea...
# NL  {'Dimapur': {'delta': {'confirmed': 3, 'deceas...
# OR  {'Angul': {'delta': {'confirmed': 1, 'recovere...
# PB  {'Amritsar': {'delta': {'confirmed': 4, 'recov...
# PY  {'Karaikal': {'delta': {'confirmed': 6, 'recov...
# RJ  {'Ajmer': {'delta': {'vaccinated1': 110, 'vacc...
# SK  {'East Sikkim': {'delta7': {'vaccinated1': 528...
# TG  {'Adilabad': {'delta': {'vaccinated1': 165, 'v...
# TN  {'Airport Quarantine': {'delta21_14': {'confir...
# TR  {'Dhalai': {'delta': {'vaccinated1': 5, 'vacci...
# TT                                                NaN
# UP  {'Agra': {'delta': {'vaccinated1': 178, 'vacci...
# UT  {'Almora': {'delta': {'vaccinated1': 37, 'vacc...
# WB  {'Alipurduar': {'delta': {'confirmed': 4, 'rec...
#
#                                                  meta  \
# AN  {'date': '2021-10-31', 'last_updated': '2021-1...
# AP  {'date': '2021-10-31', 'last_updated': '2021-1...
# AR  {'date': '2021-10-31', 'last_updated': '2021-1...
# AS  {'date': '2021-10-31', 'last_updated': '2021-1...
# BR  {'date': '2021-10-31', 'last_updated': '2021-1...
# CH  {'date': '2021-10-31', 'last_updated': '2021-1...
# CT  {'date': '2021-10-31', 'last_updated': '2021-1...
# DL  {'date': '2021-10-31', 'last_updated': '2021-1...
# DN  {'date': '2021-10-31', 'last_updated': '2021-1...
# GA  {'date': '2021-10-31', 'last_updated': '2021-1...
# GJ  {'date': '2021-10-31', 'last_updated': '2021-1...
# HP  {'date': '2021-10-31', 'last_updated': '2021-1...
# HR  {'date': '2021-10-31', 'last_updated': '2021-1...
# JH  {'date': '2021-10-31', 'last_updated': '2021-1...
# JK  {'date': '2021-10-31', 'last_updated': '2021-1...
# KA  {'date': '2021-10-31', 'last_updated': '2021-1...
# KL  {'date': '2021-10-31', 'last_updated': '2021-1...
# LA  {'date': '2021-10-31', 'last_updated': '2021-1...
# LD  {'date': '2021-10-31', 'last_updated': '2021-1...
# MH  {'date': '2021-10-31', 'last_updated': '2021-1...
# ML  {'date': '2021-10-31', 'last_updated': '2021-1...
# MN  {'date': '2021-10-31', 'last_updated': '2021-1...
# MP  {'date': '2021-10-31', 'last_updated': '2021-1...
# MZ  {'date': '2021-10-31', 'last_updated': '2021-1...
# NL  {'date': '2021-10-31', 'last_updated': '2021-1...
# OR  {'date': '2021-10-31', 'last_updated': '2021-1...
# PB  {'date': '2021-10-31', 'last_updated': '2021-1...
# PY  {'date': '2021-10-31', 'last_updated': '2021-1...
# RJ  {'date': '2021-10-31', 'last_updated': '2021-1...
# SK  {'date': '2021-10-31', 'last_updated': '2021-1...
# TG  {'date': '2021-10-31', 'last_updated': '2021-1...
# TN  {'date': '2021-10-31', 'last_updated': '2021-1...
# TR  {'date': '2021-10-31', 'last_updated': '2021-1...
# TT  {'date': '2021-10-31', 'last_updated': '2021-1...
# UP  {'date': '2021-10-31', 'last_updated': '2021-1...
# UT  {'date': '2021-10-31', 'last_updated': '2021-1...
# WB  {'date': '2021-10-31', 'last_updated': '2021-1...
#
#                                                 total
# AN  {'confirmed': 7651, 'deceased': 129, 'recovere...
# AP  {'confirmed': 2066450, 'deceased': 14373, 'rec...
# AR  {'confirmed': 55155, 'deceased': 280, 'recover...
# AS  {'confirmed': 610645, 'deceased': 5997, 'other...
# BR  {'confirmed': 726098, 'deceased': 9661, 'other...
# CH  {'confirmed': 65351, 'deceased': 820, 'recover...
# CT  {'confirmed': 1006052, 'deceased': 13577, 'rec...
# DL  {'confirmed': 1439870, 'deceased': 25091, 'rec...
# DN  {'confirmed': 10681, 'deceased': 4, 'other': 3...
# GA  {'confirmed': 178108, 'deceased': 3364, 'recov...
# GJ  {'confirmed': 826577, 'deceased': 10089, 'reco...
# HP  {'confirmed': 224106, 'deceased': 3738, 'other...
# HR  {'confirmed': 771252, 'deceased': 10049, 'reco...
# JH  {'confirmed': 348764, 'deceased': 5138, 'recov...
# JK  {'confirmed': 332249, 'deceased': 4432, 'recov...
# KA  {'confirmed': 2988333, 'deceased': 38082, 'oth...
# KL  {'confirmed': 4968657, 'deceased': 31681, 'oth...
# LA  {'confirmed': 20962, 'deceased': 208, 'recover...
# LD  {'confirmed': 10365, 'deceased': 51, 'other': ...
# MH  {'confirmed': 6611078, 'deceased': 140216, 'ot...
# ML  {'confirmed': 83627, 'deceased': 1450, 'recove...
# MN  {'confirmed': 123731, 'deceased': 1921, 'recov...
# MP  {'confirmed': 792854, 'deceased': 10524, 'reco...
# MZ  {'confirmed': 121359, 'deceased': 432, 'recove...
# NL  {'confirmed': 31842, 'deceased': 685, 'other':...
# OR  {'confirmed': 1041457, 'deceased': 8386, 'reco...
# PB  {'confirmed': 602401, 'deceased': 16559, 'reco...
# PY  {'confirmed': 128013, 'deceased': 1857, 'recov...
# RJ  {'confirmed': 954429, 'deceased': 8954, 'recov...
# SK  {'confirmed': 31979, 'deceased': 396, 'other':...
# TG  {'confirmed': 671463, 'deceased': 3956, 'recov...
# TN  {'confirmed': 2702623, 'deceased': 36116, 'rec...
# TR  {'confirmed': 84468, 'deceased': 813, 'other':...
# TT  {'confirmed': 34285612, 'deceased': 458470, 'o...
# UP  {'confirmed': 1710158, 'deceased': 22900, 'rec...
# UT  {'confirmed': 343896, 'deceased': 7400, 'other...
# WB  {'confirmed': 1592908, 'deceased': 19141, 'rec...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37 entries, AN to WB
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   delta       37 non-null     object
#  1   delta21_14  36 non-null     object
#  2   delta7      37 non-null     object
#  3   districts   36 non-null     object
#  4   meta        37 non-null     object
#  5   total       37 non-null     object
# dtypes: object(6)
# memory usage: 2.0+ KB

# %% [markdown]
# # identifying on which columns we have nulls

# %%
df.isnull().sum()
# Out:
# delta         0
# delta21_14    1
# delta7        0
# districts     1
# meta          0
# total         0
# dtype: int64

# %% [markdown]
# # so we have found nulls in delta21_14,districts  so we must drop the extra nulls

# %%
df.dropna(subset=['delta21_14','districts'],inplace=True)

# %% [markdown]
# # checking whether nuuls are dropped or not

# %%
df.isnull().sum()
# Out:
# delta         0
# delta21_14    0
# delta7        0
# districts     0
# meta          0
# total         0
# dtype: int64

# %% [markdown]
# # all the nulls of outer table dropped so lets extract one by one

# %%
pd.DataFrame(data=[x for x in df["delta"]],index=df["delta"].keys())
# Out:
#       tested  vaccinated1  vaccinated2  confirmed  deceased  recovered  other
# AN    1376.0          3.0         13.0        NaN       NaN        NaN    NaN
# AP   39848.0      20497.0      24137.0      385.0       4.0      675.0    NaN
# AR     334.0         42.0        195.0        1.0       NaN        9.0    NaN
# AS   15060.0      19124.0      37463.0      212.0       1.0      236.0    NaN
# BR  226443.0     114694.0     145827.0        8.0       NaN        9.0    NaN
# CH    1403.0        211.0       1282.0        5.0       NaN        3.0    NaN
# CT   11869.0      21312.0      39393.0       32.0       1.0       32.0    NaN
# DL   56751.0      12482.0      11839.0       45.0       NaN       46.0    NaN
# DN       NaN          3.0         20.0        NaN       NaN        1.0    NaN
# GA    2361.0       2572.0      12404.0       23.0       NaN       53.0    NaN
# GJ   34282.0      14685.0      62096.0       20.0       NaN       23.0    NaN
# HP    3613.0        371.0       8192.0       85.0       1.0      198.0    NaN
# HR   20588.0       7867.0      15801.0       11.0       NaN       10.0    NaN
# JH   31238.0      41034.0      51488.0       10.0       NaN        8.0    NaN
# JK   38915.0       1584.0      45202.0       95.0       NaN       79.0    NaN
# KA  106939.0      17604.0      28163.0      292.0      11.0      345.0    NaN
# KL   65158.0       2010.0      11914.0     7167.0     167.0     6439.0    NaN
# LA     388.0          NaN          2.0       11.0       NaN        9.0    NaN
# MH  108040.0      53161.0      31988.0     1172.0      20.0     1399.0    NaN
# ML    1559.0         38.0        203.0       22.0       1.0       51.0    NaN
# MN    1689.0        705.0       4283.0       63.0       1.0       62.0    NaN
# MP   55368.0       5713.0      77062.0       16.0       NaN        8.0    NaN
# MZ    5945.0         10.0         51.0      579.0       2.0      610.0    NaN
# NL     468.0        193.0        822.0       11.0       1.0       21.0    1.0
# OR   69675.0      21420.0      25651.0      488.0       4.0      450.0    NaN
# PB   34152.0       3321.0       4418.0       26.0       1.0       25.0    NaN
# PY    2662.0        171.0        532.0       38.0       NaN       45.0    NaN
# RJ   13454.0       9399.0      29672.0        2.0       NaN        2.0    NaN
# SK     389.0          NaN          NaN       21.0       1.0        8.0    NaN
# TG   25021.0      38781.0      26738.0      121.0       1.0      183.0    NaN
# TN  123701.0      77325.0     106584.0     1009.0      19.0     1183.0    NaN
# TR    3501.0          3.0        650.0       12.0       NaN        2.0    NaN
# UP  161458.0      53401.0      57556.0        6.0       NaN        6.0    NaN
# UT    9524.0       1065.0      12934.0        5.0       NaN        9.0    NaN
# WB   47417.0     209609.0      58881.0      914.0      15.0      913.0    NaN

# %% [markdown]
# # in delta table we dont need other column since includes nulls removing column from dataframe,if there are rows with all places nulls then mention index and axis=0

# %%
pd.DataFrame(data=[x for x in df["delta"]],index=df["delta"].keys()).drop('other',axis=1)
# Out:
#       tested  vaccinated1  vaccinated2  confirmed  deceased  recovered
# AN    1376.0          3.0         13.0        NaN       NaN        NaN
# AP   39848.0      20497.0      24137.0      385.0       4.0      675.0
# AR     334.0         42.0        195.0        1.0       NaN        9.0
# AS   15060.0      19124.0      37463.0      212.0       1.0      236.0
# BR  226443.0     114694.0     145827.0        8.0       NaN        9.0
# CH    1403.0        211.0       1282.0        5.0       NaN        3.0
# CT   11869.0      21312.0      39393.0       32.0       1.0       32.0
# DL   56751.0      12482.0      11839.0       45.0       NaN       46.0
# DN       NaN          3.0         20.0        NaN       NaN        1.0
# GA    2361.0       2572.0      12404.0       23.0       NaN       53.0
# GJ   34282.0      14685.0      62096.0       20.0       NaN       23.0
# HP    3613.0        371.0       8192.0       85.0       1.0      198.0
# HR   20588.0       7867.0      15801.0       11.0       NaN       10.0
# JH   31238.0      41034.0      51488.0       10.0       NaN        8.0
# JK   38915.0       1584.0      45202.0       95.0       NaN       79.0
# KA  106939.0      17604.0      28163.0      292.0      11.0      345.0
# KL   65158.0       2010.0      11914.0     7167.0     167.0     6439.0
# LA     388.0          NaN          2.0       11.0       NaN        9.0
# MH  108040.0      53161.0      31988.0     1172.0      20.0     1399.0
# ML    1559.0         38.0        203.0       22.0       1.0       51.0
# MN    1689.0        705.0       4283.0       63.0       1.0       62.0
# MP   55368.0       5713.0      77062.0       16.0       NaN        8.0
# MZ    5945.0         10.0         51.0      579.0       2.0      610.0
# NL     468.0        193.0        822.0       11.0       1.0       21.0
# OR   69675.0      21420.0      25651.0      488.0       4.0      450.0
# PB   34152.0       3321.0       4418.0       26.0       1.0       25.0
# PY    2662.0        171.0        532.0       38.0       NaN       45.0
# RJ   13454.0       9399.0      29672.0        2.0       NaN        2.0
# SK     389.0          NaN          NaN       21.0       1.0        8.0
# TG   25021.0      38781.0      26738.0      121.0       1.0      183.0
# TN  123701.0      77325.0     106584.0     1009.0      19.0     1183.0
# TR    3501.0          3.0        650.0       12.0       NaN        2.0
# UP  161458.0      53401.0      57556.0        6.0       NaN        6.0
# UT    9524.0       1065.0      12934.0        5.0       NaN        9.0
# WB   47417.0     209609.0      58881.0      914.0      15.0      913.0

# %% [markdown]
# # to get on how many nulls present in each column ?

# %%
pd.DataFrame(data=[x for x in df["delta"]],index=df["delta"].keys()).drop('other',axis=1).isnull().sum()
# Out:
# tested          1
# vaccinated1     2
# vaccinated2     1
# confirmed       2
# deceased       18
# recovered       1
# dtype: int64

# %% [markdown]
# # removing the rows which are contains nulls in the whole row

# %%
delta_T=pd.DataFrame(data=[x for x in df["delta"]],index=df["delta"].keys()).drop('other',axis=1).dropna(how='all')
delta_T
# Out:
#       tested  vaccinated1  vaccinated2  confirmed  deceased  recovered
# AN    1376.0          3.0         13.0        NaN       NaN        NaN
# AP   39848.0      20497.0      24137.0      385.0       4.0      675.0
# AR     334.0         42.0        195.0        1.0       NaN        9.0
# AS   15060.0      19124.0      37463.0      212.0       1.0      236.0
# BR  226443.0     114694.0     145827.0        8.0       NaN        9.0
# CH    1403.0        211.0       1282.0        5.0       NaN        3.0
# CT   11869.0      21312.0      39393.0       32.0       1.0       32.0
# DL   56751.0      12482.0      11839.0       45.0       NaN       46.0
# DN       NaN          3.0         20.0        NaN       NaN        1.0
# GA    2361.0       2572.0      12404.0       23.0       NaN       53.0
# GJ   34282.0      14685.0      62096.0       20.0       NaN       23.0
# HP    3613.0        371.0       8192.0       85.0       1.0      198.0
# HR   20588.0       7867.0      15801.0       11.0       NaN       10.0
# JH   31238.0      41034.0      51488.0       10.0       NaN        8.0
# JK   38915.0       1584.0      45202.0       95.0       NaN       79.0
# KA  106939.0      17604.0      28163.0      292.0      11.0      345.0
# KL   65158.0       2010.0      11914.0     7167.0     167.0     6439.0
# LA     388.0          NaN          2.0       11.0       NaN        9.0
# MH  108040.0      53161.0      31988.0     1172.0      20.0     1399.0
# ML    1559.0         38.0        203.0       22.0       1.0       51.0
# MN    1689.0        705.0       4283.0       63.0       1.0       62.0
# MP   55368.0       5713.0      77062.0       16.0       NaN        8.0
# MZ    5945.0         10.0         51.0      579.0       2.0      610.0
# NL     468.0        193.0        822.0       11.0       1.0       21.0
# OR   69675.0      21420.0      25651.0      488.0       4.0      450.0
# PB   34152.0       3321.0       4418.0       26.0       1.0       25.0
# PY    2662.0        171.0        532.0       38.0       NaN       45.0
# RJ   13454.0       9399.0      29672.0        2.0       NaN        2.0
# SK     389.0          NaN          NaN       21.0       1.0        8.0
# TG   25021.0      38781.0      26738.0      121.0       1.0      183.0
# TN  123701.0      77325.0     106584.0     1009.0      19.0     1183.0
# TR    3501.0          3.0        650.0       12.0       NaN        2.0
# UP  161458.0      53401.0      57556.0        6.0       NaN        6.0
# UT    9524.0       1065.0      12934.0        5.0       NaN        9.0
# WB   47417.0     209609.0      58881.0      914.0      15.0      913.0

# %% [markdown]
# # replacing all the nulls of columns in above dataframe with 0

# %% [markdown]
# # delta final table after data cleaning as delta_T

# %%
delta_T.fillna(value=0,inplace=True)
delta_T
# Out:
#       tested  vaccinated1  vaccinated2  confirmed  deceased  recovered
# AN    1376.0          3.0         13.0        0.0       0.0        0.0
# AP   39848.0      20497.0      24137.0      385.0       4.0      675.0
# AR     334.0         42.0        195.0        1.0       0.0        9.0
# AS   15060.0      19124.0      37463.0      212.0       1.0      236.0
# BR  226443.0     114694.0     145827.0        8.0       0.0        9.0
# CH    1403.0        211.0       1282.0        5.0       0.0        3.0
# CT   11869.0      21312.0      39393.0       32.0       1.0       32.0
# DL   56751.0      12482.0      11839.0       45.0       0.0       46.0
# DN       0.0          3.0         20.0        0.0       0.0        1.0
# GA    2361.0       2572.0      12404.0       23.0       0.0       53.0
# GJ   34282.0      14685.0      62096.0       20.0       0.0       23.0
# HP    3613.0        371.0       8192.0       85.0       1.0      198.0
# HR   20588.0       7867.0      15801.0       11.0       0.0       10.0
# JH   31238.0      41034.0      51488.0       10.0       0.0        8.0
# JK   38915.0       1584.0      45202.0       95.0       0.0       79.0
# KA  106939.0      17604.0      28163.0      292.0      11.0      345.0
# KL   65158.0       2010.0      11914.0     7167.0     167.0     6439.0
# LA     388.0          0.0          2.0       11.0       0.0        9.0
# MH  108040.0      53161.0      31988.0     1172.0      20.0     1399.0
# ML    1559.0         38.0        203.0       22.0       1.0       51.0
# MN    1689.0        705.0       4283.0       63.0       1.0       62.0
# MP   55368.0       5713.0      77062.0       16.0       0.0        8.0
# MZ    5945.0         10.0         51.0      579.0       2.0      610.0
# NL     468.0        193.0        822.0       11.0       1.0       21.0
# OR   69675.0      21420.0      25651.0      488.0       4.0      450.0
# PB   34152.0       3321.0       4418.0       26.0       1.0       25.0
# PY    2662.0        171.0        532.0       38.0       0.0       45.0
# RJ   13454.0       9399.0      29672.0        2.0       0.0        2.0
# SK     389.0          0.0          0.0       21.0       1.0        8.0
# TG   25021.0      38781.0      26738.0      121.0       1.0      183.0
# TN  123701.0      77325.0     106584.0     1009.0      19.0     1183.0
# TR    3501.0          3.0        650.0       12.0       0.0        2.0
# UP  161458.0      53401.0      57556.0        6.0       0.0        6.0
# UT    9524.0       1065.0      12934.0        5.0       0.0        9.0
# WB   47417.0     209609.0      58881.0      914.0      15.0      913.0

# %%
delta_T.index.name='State_code'
delta_T
# Out:
#               tested  vaccinated1  vaccinated2  confirmed  deceased  recovered
# State_code
# AN            1376.0          3.0         13.0        0.0       0.0        0.0
# AP           39848.0      20497.0      24137.0      385.0       4.0      675.0
# AR             334.0         42.0        195.0        1.0       0.0        9.0
# AS           15060.0      19124.0      37463.0      212.0       1.0      236.0
# BR          226443.0     114694.0     145827.0        8.0       0.0        9.0
# CH            1403.0        211.0       1282.0        5.0       0.0        3.0
# CT           11869.0      21312.0      39393.0       32.0       1.0       32.0
# DL           56751.0      12482.0      11839.0       45.0       0.0       46.0
# DN               0.0          3.0         20.0        0.0       0.0        1.0
# GA            2361.0       2572.0      12404.0       23.0       0.0       53.0
# GJ           34282.0      14685.0      62096.0       20.0       0.0       23.0
# HP            3613.0        371.0       8192.0       85.0       1.0      198.0
# HR           20588.0       7867.0      15801.0       11.0       0.0       10.0
# JH           31238.0      41034.0      51488.0       10.0       0.0        8.0
# JK           38915.0       1584.0      45202.0       95.0       0.0       79.0
# KA          106939.0      17604.0      28163.0      292.0      11.0      345.0
# KL           65158.0       2010.0      11914.0     7167.0     167.0     6439.0
# LA             388.0          0.0          2.0       11.0       0.0        9.0
# MH          108040.0      53161.0      31988.0     1172.0      20.0     1399.0
# ML            1559.0         38.0        203.0       22.0       1.0       51.0
# MN            1689.0        705.0       4283.0       63.0       1.0       62.0
# MP           55368.0       5713.0      77062.0       16.0       0.0        8.0
# MZ            5945.0         10.0         51.0      579.0       2.0      610.0
# NL             468.0        193.0        822.0       11.0       1.0       21.0
# OR           69675.0      21420.0      25651.0      488.0       4.0      450.0
# PB           34152.0       3321.0       4418.0       26.0       1.0       25.0
# PY            2662.0        171.0        532.0       38.0       0.0       45.0
# RJ           13454.0       9399.0      29672.0        2.0       0.0        2.0
# SK             389.0          0.0          0.0       21.0       1.0        8.0
# TG           25021.0      38781.0      26738.0      121.0       1.0      183.0
# TN          123701.0      77325.0     106584.0     1009.0      19.0     1183.0
# TR            3501.0          3.0        650.0       12.0       0.0        2.0
# UP          161458.0      53401.0      57556.0        6.0       0.0        6.0
# UT            9524.0       1065.0      12934.0        5.0       0.0        9.0
# WB           47417.0     209609.0      58881.0      914.0      15.0      913.0

# %%
delta_T.to_csv(r"C:\Users\Admin\Desktop\New_Project\csv\Delta.csv")

# %% [markdown]
# # delta21_14

# %% [markdown]
# # delta21_14 final table after data cleaning

# %%
pd.DataFrame(data=[x for x in df["delta21_14"]],index=df["delta21_14"].keys())
# Out:
#     confirmed
# AN          9
# AP       3220
# AR         87
# AS       1499
# BR         30
# CH         23
# CT        124
# DL        195
# DN          4
# GA        409
# GJ        149
# HP        958
# HR         83
# JH         78
# JK        529
# KA       2432
# KL      59521
# LA         26
# MH      13825
# ML        530
# MN        734
# MP         63
# MZ       6770
# NL        162
# OR       3381
# PB        159
# PY        343
# RJ         31
# SK         82
# TG       1068
# TN       8827
# TR         49
# UP         74
# UT         88
# WB       4193

# %% [markdown]
# # counting nulls

# %%
pd.DataFrame(data=[x for x in df["delta21_14"]],index=df["delta21_14"].keys()).isnull().sum()
# Out:
# confirmed    0
# dtype: int64

# %%
pd.DataFrame(data=[x for x in df["delta21_14"]],index=df["delta21_14"].keys()).index.name='State_code'

# %%
pd.DataFrame(data=[x for x in df["delta21_14"]],index=df["delta21_14"].keys()).to_csv(r"C:\Users\Admin\Desktop\New_Project\csv\delta21_14.csv")

# %% [markdown]
# # delta7

# %%
pd.DataFrame(data=[x for x in df["delta7"]],index=df["delta7"].keys())
# Out:
#             confirmed  recovered     tested  vaccinated1  vaccinated2  \
# State_code
# AN                3.0          5     8936.0          884        10640
# AP             2873.0       3590   254532.0      1223010      1887005
# AR               66.0         97     4788.0         3312        23647
# AS             2056.0       2215   269097.0       274869       849889
# BR               40.0         31  1378539.0      1286708      2144970
# CH               28.0         20    10726.0         3680        21641
# CT              205.0        103   147451.0       379374       604260
# DL              267.0        239   395086.0       160323       269146
# DN                NaN          2        NaN         2802        14244
# GA              222.0        409    19026.0         8418        46494
# GJ              159.0        116   328489.0       335172      1660382
# HP             1537.0       1154    64352.0        13244       234011
# HR               95.0         87   148110.0       160777       368141
# JH              137.0        250   464579.0       299587       428313
# JK              611.0        572   254608.0        33383       414843
# KA             2347.0       2339   724215.0       623591      1373861
# KL            53326.0      48406   506604.0       109805       792534
# LA               58.0         28     2475.0          525         1532
# MH             8117.0      15146   773516.0      1611778      1282938
# ML              256.0        460    13944.0         7871        41927
# MN              439.0        652    12787.0         7665        71276
# MP              105.0         74   393209.0       148817      2034460
# MZ             4098.0       5685    42841.0         4302        11262
# NL              130.0        144     4606.0         4706        23628
# OR             3046.0       3230   473919.0       731837       917236
# PB              192.0        162   221114.0       200182       223256
# PY              278.0        315    21095.0         8324        20073
# RJ               27.0         26    95132.0       271500       864947
# SK               79.0         76     2847.0          782        14044
# TG             1189.0       1121   261086.0      1072389       961422
# TN             7407.0       8852   858304.0       788134      1578082
# TR               87.0         62    22126.0         4155        74642
# UP               63.0         58  1140736.0      2266921      3130828
# UT               75.0         74    83377.0        25250       258381
# WB             6453.0       5953   300114.0      3809597      1871612
#
#             deceased  other
# State_code
# AN               NaN    NaN
# AP              30.0    NaN
# AR               NaN    NaN
# AS              24.0    NaN
# BR               NaN    NaN
# CH               NaN    NaN
# CT               5.0    NaN
# DL               NaN    NaN
# DN               NaN    NaN
# GA               6.0    NaN
# GJ               2.0    NaN
# HP              20.0   -1.0
# HR               NaN    NaN
# JH               3.0    NaN
# JK               3.0    NaN
# KA              75.0    NaN
# KL            3089.0    NaN
# LA               NaN    NaN
# MH             200.0    7.0
# ML               4.0    NaN
# MN              10.0    NaN
# MP               1.0    NaN
# MZ              21.0    NaN
# NL               6.0   13.0
# OR              24.0    NaN
# PB               8.0    NaN
# PY               NaN    NaN
# RJ               NaN    NaN
# SK               2.0    6.0
# TG               9.0    NaN
# TN              97.0    NaN
# TR               NaN    NaN
# UP               1.0    NaN
# UT               1.0   12.0
# WB              86.0    NaN

# %%
pd.DataFrame(data=[x for x in df["delta7"]],index=df["delta7"].keys()).drop('other',axis=1)
# Out:
#             confirmed  recovered     tested  vaccinated1  vaccinated2  \
# State_code
# AN                3.0          5     8936.0          884        10640
# AP             2873.0       3590   254532.0      1223010      1887005
# AR               66.0         97     4788.0         3312        23647
# AS             2056.0       2215   269097.0       274869       849889
# BR               40.0         31  1378539.0      1286708      2144970
# CH               28.0         20    10726.0         3680        21641
# CT              205.0        103   147451.0       379374       604260
# DL              267.0        239   395086.0       160323       269146
# DN                NaN          2        NaN         2802        14244
# GA              222.0        409    19026.0         8418        46494
# GJ              159.0        116   328489.0       335172      1660382
# HP             1537.0       1154    64352.0        13244       234011
# HR               95.0         87   148110.0       160777       368141
# JH              137.0        250   464579.0       299587       428313
# JK              611.0        572   254608.0        33383       414843
# KA             2347.0       2339   724215.0       623591      1373861
# KL            53326.0      48406   506604.0       109805       792534
# LA               58.0         28     2475.0          525         1532
# MH             8117.0      15146   773516.0      1611778      1282938
# ML              256.0        460    13944.0         7871        41927
# MN              439.0        652    12787.0         7665        71276
# MP              105.0         74   393209.0       148817      2034460
# MZ             4098.0       5685    42841.0         4302        11262
# NL              130.0        144     4606.0         4706        23628
# OR             3046.0       3230   473919.0       731837       917236
# PB              192.0        162   221114.0       200182       223256
# PY              278.0        315    21095.0         8324        20073
# RJ               27.0         26    95132.0       271500       864947
# SK               79.0         76     2847.0          782        14044
# TG             1189.0       1121   261086.0      1072389       961422
# TN             7407.0       8852   858304.0       788134      1578082
# TR               87.0         62    22126.0         4155        74642
# UP               63.0         58  1140736.0      2266921      3130828
# UT               75.0         74    83377.0        25250       258381
# WB             6453.0       5953   300114.0      3809597      1871612
#
#             deceased
# State_code
# AN               NaN
# AP              30.0
# AR               NaN
# AS              24.0
# BR               NaN
# CH               NaN
# CT               5.0
# DL               NaN
# DN               NaN
# GA               6.0
# GJ               2.0
# HP              20.0
# HR               NaN
# JH               3.0
# JK               3.0
# KA              75.0
# KL            3089.0
# LA               NaN
# MH             200.0
# ML               4.0
# MN              10.0
# MP               1.0
# MZ              21.0
# NL               6.0
# OR              24.0
# PB               8.0
# PY               NaN
# RJ               NaN
# SK               2.0
# TG               9.0
# TN              97.0
# TR               NaN
# UP               1.0
# UT               1.0
# WB              86.0

# %%
delta7_T=pd.DataFrame(data=[x for x in df["delta7"]],index=df["delta7"].keys()).drop('other',axis=1).dropna(how='all')
delta7_T
# Out:
#             confirmed  recovered     tested  vaccinated1  vaccinated2  \
# State_code
# AN                3.0          5     8936.0          884        10640
# AP             2873.0       3590   254532.0      1223010      1887005
# AR               66.0         97     4788.0         3312        23647
# AS             2056.0       2215   269097.0       274869       849889
# BR               40.0         31  1378539.0      1286708      2144970
# CH               28.0         20    10726.0         3680        21641
# CT              205.0        103   147451.0       379374       604260
# DL              267.0        239   395086.0       160323       269146
# DN                NaN          2        NaN         2802        14244
# GA              222.0        409    19026.0         8418        46494
# GJ              159.0        116   328489.0       335172      1660382
# HP             1537.0       1154    64352.0        13244       234011
# HR               95.0         87   148110.0       160777       368141
# JH              137.0        250   464579.0       299587       428313
# JK              611.0        572   254608.0        33383       414843
# KA             2347.0       2339   724215.0       623591      1373861
# KL            53326.0      48406   506604.0       109805       792534
# LA               58.0         28     2475.0          525         1532
# MH             8117.0      15146   773516.0      1611778      1282938
# ML              256.0        460    13944.0         7871        41927
# MN              439.0        652    12787.0         7665        71276
# MP              105.0         74   393209.0       148817      2034460
# MZ             4098.0       5685    42841.0         4302        11262
# NL              130.0        144     4606.0         4706        23628
# OR             3046.0       3230   473919.0       731837       917236
# PB              192.0        162   221114.0       200182       223256
# PY              278.0        315    21095.0         8324        20073
# RJ               27.0         26    95132.0       271500       864947
# SK               79.0         76     2847.0          782        14044
# TG             1189.0       1121   261086.0      1072389       961422
# TN             7407.0       8852   858304.0       788134      1578082
# TR               87.0         62    22126.0         4155        74642
# UP               63.0         58  1140736.0      2266921      3130828
# UT               75.0         74    83377.0        25250       258381
# WB             6453.0       5953   300114.0      3809597      1871612
#
#             deceased
# State_code
# AN               NaN
# AP              30.0
# AR               NaN
# AS              24.0
# BR               NaN
# CH               NaN
# CT               5.0
# DL               NaN
# DN               NaN
# GA               6.0
# GJ               2.0
# HP              20.0
# HR               NaN
# JH               3.0
# JK               3.0
# KA              75.0
# KL            3089.0
# LA               NaN
# MH             200.0
# ML               4.0
# MN              10.0
# MP               1.0
# MZ              21.0
# NL               6.0
# OR              24.0
# PB               8.0
# PY               NaN
# RJ               NaN
# SK               2.0
# TG               9.0
# TN              97.0
# TR               NaN
# UP               1.0
# UT               1.0
# WB              86.0

# %%
delta7_T.isnull().sum()
# Out:
# confirmed       1
# recovered       0
# tested          1
# vaccinated1     0
# vaccinated2     0
# deceased       11
# dtype: int64

# %% [markdown]
# # delta7 table after data cleaning as delta7_T

# %%
delta7_T.fillna(0,inplace=True)
delta7_T
# Out:
#             confirmed  recovered     tested  vaccinated1  vaccinated2  \
# State_code
# AN                3.0          5     8936.0          884        10640
# AP             2873.0       3590   254532.0      1223010      1887005
# AR               66.0         97     4788.0         3312        23647
# AS             2056.0       2215   269097.0       274869       849889
# BR               40.0         31  1378539.0      1286708      2144970
# CH               28.0         20    10726.0         3680        21641
# CT              205.0        103   147451.0       379374       604260
# DL              267.0        239   395086.0       160323       269146
# DN                0.0          2        0.0         2802        14244
# GA              222.0        409    19026.0         8418        46494
# GJ              159.0        116   328489.0       335172      1660382
# HP             1537.0       1154    64352.0        13244       234011
# HR               95.0         87   148110.0       160777       368141
# JH              137.0        250   464579.0       299587       428313
# JK              611.0        572   254608.0        33383       414843
# KA             2347.0       2339   724215.0       623591      1373861
# KL            53326.0      48406   506604.0       109805       792534
# LA               58.0         28     2475.0          525         1532
# MH             8117.0      15146   773516.0      1611778      1282938
# ML              256.0        460    13944.0         7871        41927
# MN              439.0        652    12787.0         7665        71276
# MP              105.0         74   393209.0       148817      2034460
# MZ             4098.0       5685    42841.0         4302        11262
# NL              130.0        144     4606.0         4706        23628
# OR             3046.0       3230   473919.0       731837       917236
# PB              192.0        162   221114.0       200182       223256
# PY              278.0        315    21095.0         8324        20073
# RJ               27.0         26    95132.0       271500       864947
# SK               79.0         76     2847.0          782        14044
# TG             1189.0       1121   261086.0      1072389       961422
# TN             7407.0       8852   858304.0       788134      1578082
# TR               87.0         62    22126.0         4155        74642
# UP               63.0         58  1140736.0      2266921      3130828
# UT               75.0         74    83377.0        25250       258381
# WB             6453.0       5953   300114.0      3809597      1871612
#
#             deceased
# State_code
# AN               0.0
# AP              30.0
# AR               0.0
# AS              24.0
# BR               0.0
# CH               0.0
# CT               5.0
# DL               0.0
# DN               0.0
# GA               6.0
# GJ               2.0
# HP              20.0
# HR               0.0
# JH               3.0
# JK               3.0
# KA              75.0
# KL            3089.0
# LA               0.0
# MH             200.0
# ML               4.0
# MN              10.0
# MP               1.0
# MZ              21.0
# NL               6.0
# OR              24.0
# PB               8.0
# PY               0.0
# RJ               0.0
# SK               2.0
# TG               9.0
# TN              97.0
# TR               0.0
# UP               1.0
# UT               1.0
# WB              86.0

# %%
delta7_T.to_csv(r"C:\Users\Admin\Desktop\New_Project\csv\Delta7.csv")

# %% [markdown]
# # meta

# %%
pd.DataFrame(data=[x for x in df["meta"]],index=df["meta"].keys())
# Out:
#                   date               last_updated  population  \
# State_code
# AN          2021-10-31  2021-11-01T11:03:10+05:30      397000
# AP          2021-10-31  2021-11-01T09:54:14+05:30    52221000
# AR          2021-10-31  2021-11-01T11:20:24+05:30     1504000
# AS          2021-10-31  2021-11-01T09:54:14+05:30    34293000
# BR          2021-10-31  2021-11-01T09:54:14+05:30   119520000
# CH          2021-10-31  2021-11-01T09:54:14+05:30     1179000
# CT          2021-10-31  2021-11-01T09:54:14+05:30    28724000
# DL          2021-10-31  2021-11-01T09:54:14+05:30    19814000
# DN          2021-10-31  2021-11-01T09:54:14+05:30      959000
# GA          2021-10-31  2021-11-01T09:54:14+05:30     1540000
# GJ          2021-10-31  2021-11-01T09:54:14+05:30    67936000
# HP          2021-10-31  2021-11-01T09:54:14+05:30     7300000
# HR          2021-10-31  2021-11-01T09:54:14+05:30    28672000
# JH          2021-10-31  2021-11-01T09:54:14+05:30    37403000
# JK          2021-10-31  2021-11-01T09:54:14+05:30    13203000
# KA          2021-10-31  2021-11-01T09:54:14+05:30    65798000
# KL          2021-10-31  2021-11-01T09:54:14+05:30    35125000
# LA          2021-10-31  2021-11-01T09:54:14+05:30      293000
# MH          2021-10-31  2021-11-01T09:54:14+05:30   122153000
# ML          2021-10-31  2021-11-01T09:54:14+05:30     3224000
# MN          2021-10-31  2021-11-01T09:54:14+05:30     3103000
# MP          2021-10-31  2021-11-01T09:54:14+05:30    82232000
# MZ          2021-10-31  2021-11-01T09:54:14+05:30     1192000
# NL          2021-10-31  2021-11-01T09:54:14+05:30     2150000
# OR          2021-10-31  2021-11-01T09:54:14+05:30    43671000
# PB          2021-10-31  2021-11-01T09:54:14+05:30    29859000
# PY          2021-10-31  2021-11-01T09:54:14+05:30     1504000
# RJ          2021-10-31  2021-11-01T09:54:14+05:30    77264000
# SK          2021-10-31  2021-10-31T20:49:45+05:30      664000
# TG          2021-10-31  2021-11-01T09:54:14+05:30    37220000
# TN          2021-10-31  2021-11-01T09:54:14+05:30    75695000
# TR          2021-10-31  2021-11-01T09:54:14+05:30     3992000
# UP          2021-10-31  2021-11-01T09:54:14+05:30   224979000
# UT          2021-10-31  2021-11-01T09:54:14+05:30    11141000
# WB          2021-10-31  2021-11-01T09:54:14+05:30    96906000
#
#                                                        tested  \
# State_code
# AN          {'date': '2021-10-31', 'source': 'https://dhs....
# AP          {'date': '2021-10-31', 'source': 'https://twit...
# AR          {'date': '2021-10-31', 'source': 'https://twit...
# AS          {'date': '2021-10-31', 'source': 'https://twit...
# BR          {'date': '2021-10-31', 'source': 'https://twit...
# CH          {'date': '2021-10-31', 'source': 'https://t.me...
# CT          {'date': '2021-10-31', 'source': 'https://twit...
# DL          {'date': '2021-10-31', 'source': 'https://t.me...
# DN          {'date': '2020-10-20', 'source': 'https://dddc...
# GA          {'date': '2021-10-31', 'source': 'https://www....
# GJ          {'date': '2021-10-31', 'source': 'https://t.me...
# HP          {'date': '2021-10-31', 'source': 'https://twit...
# HR          {'date': '2021-10-31', 'source': 'http://www.n...
# JH          {'date': '2021-10-31', 'source': 'https://t.me...
# JK          {'date': '2021-10-31', 'source': 'https://twit...
# KA          {'date': '2021-10-31', 'source': 'https://t.co...
# KL          {'date': '2021-10-31', 'source': 'https://dhs....
# LA          {'date': '2021-10-31', 'source': 'https://twit...
# MH          {'date': '2021-10-31', 'source': 'https://twit...
# ML          {'date': '2021-10-31', 'source': 'https://t.me...
# MN          {'date': '2021-10-31', 'source': 'https://nrhm...
# MP          {'date': '2021-10-31', 'source': 'https://twit...
# MZ          {'date': '2021-10-31', 'source': 'https://dipr...
# NL          {'date': '2021-10-31', 'source': 'https://twit...
# OR          {'date': '2021-10-31', 'source': 'https://t.me...
# PB          {'date': '2021-10-31', 'source': 'https://t.me...
# PY          {'date': '2021-10-31', 'source': 'https://t.me...
# RJ          {'date': '2021-10-31', 'source': 'https://t.me...
# SK          {'date': '2021-10-31', 'source': 'https://t.me...
# TG          {'date': '2021-10-31', 'source': 'https://twit...
# TN          {'date': '2021-10-31', 'source': 'https://t.me...
# TR          {'date': '2021-10-31', 'source': 'https://t.me...
# UP          {'date': '2021-10-31', 'source': 'https://twit...
# UT          {'date': '2021-10-31', 'source': 'https://t.me...
# WB          {'date': '2021-10-31', 'source': 'https://www....
#
#                         vaccinated  \
# State_code
# AN          {'date': '2021-10-31'}
# AP          {'date': '2021-10-31'}
# AR          {'date': '2021-10-31'}
# AS          {'date': '2021-10-31'}
# BR          {'date': '2021-10-31'}
# CH          {'date': '2021-10-31'}
# CT          {'date': '2021-10-31'}
# DL          {'date': '2021-10-31'}
# DN          {'date': '2021-10-31'}
# GA          {'date': '2021-10-31'}
# GJ          {'date': '2021-10-31'}
# HP          {'date': '2021-10-31'}
# HR          {'date': '2021-10-31'}
# JH          {'date': '2021-10-31'}
# JK          {'date': '2021-10-31'}
# KA          {'date': '2021-10-31'}
# KL          {'date': '2021-10-31'}
# LA          {'date': '2021-10-31'}
# MH          {'date': '2021-10-31'}
# ML          {'date': '2021-10-31'}
# MN          {'date': '2021-10-31'}
# MP          {'date': '2021-10-31'}
# MZ          {'date': '2021-10-31'}
# NL          {'date': '2021-10-31'}
# OR          {'date': '2021-10-31'}
# PB          {'date': '2021-10-31'}
# PY          {'date': '2021-10-31'}
# RJ          {'date': '2021-10-31'}
# SK          {'date': '2021-10-31'}
# TG          {'date': '2021-10-31'}
# TN          {'date': '2021-10-31'}
# TR          {'date': '2021-10-31'}
# UP          {'date': '2021-10-31'}
# UT          {'date': '2021-10-31'}
# WB          {'date': '2021-10-31'}
#
#                                                         notes
# State_code
# AN                                                        NaN
# AP                                                        NaN
# AR          [July 25]: All numbers corresponding to Papum ...
# AS          [Jan 1]: 1347 cases i.e Covid +'tive patients ...
# BR          [June 9] : 3951 deceased cases have been repor...
# CH                                                        NaN
# CT                                                        NaN
# DL          [July 14]: Value for the total tests conducted...
# DN                                                        NaN
# GA                                                        NaN
# GJ                                                        NaN
# HP                                                        NaN
# HR                                                        NaN
# JH                                                        NaN
# JK                                                        NaN
# KA                                                        NaN
# KL                                                        NaN
# LA                                                        NaN
# MH          [Dec 16]:10,218 duplicate cases & other state ...
# ML                                                        NaN
# MN          [Dec 14]:824 out of 980 recovered cases are ba...
# MP          [14 Oct'20]: 4469 confirmed cases and 4469 rec...
# MZ                                                        NaN
# NL                                                        NaN
# OR          [July 12th] :20 non-covid deaths reported in s...
# PB                                                        NaN
# PY                                                        NaN
# RJ                                                        NaN
# SK                                                        NaN
# TG          [July 27] : Telangana bulletin for the previou...
# TN          [June 29 2021]: TN has introduced a new distri...
# TR          [Aug 4]: Tripura bulletin for the previous day...
# UP          [Jan 1]:As no bulletin was provided for 31'st ...
# UT          [Oct 30]: Metric of capturing the testing data...
# WB                                                        NaN

# %%
pd.DataFrame(data=[x for x in df["meta"]],index=df["meta"].keys()).isnull().sum()
# Out:
# date             0
# last_updated     0
# population       0
# tested           0
# vaccinated       0
# notes           22
# dtype: int64

# %% [markdown]
# # meta table after data cleaning

# %%
pd.DataFrame(data=[x for x in df["meta"]],index=df["meta"].keys()).drop(['last_updated','tested','vaccinated','notes'],axis=1)
# Out:
#                   date  population
# State_code
# AN          2021-10-31      397000
# AP          2021-10-31    52221000
# AR          2021-10-31     1504000
# AS          2021-10-31    34293000
# BR          2021-10-31   119520000
# CH          2021-10-31     1179000
# CT          2021-10-31    28724000
# DL          2021-10-31    19814000
# DN          2021-10-31      959000
# GA          2021-10-31     1540000
# GJ          2021-10-31    67936000
# HP          2021-10-31     7300000
# HR          2021-10-31    28672000
# JH          2021-10-31    37403000
# JK          2021-10-31    13203000
# KA          2021-10-31    65798000
# KL          2021-10-31    35125000
# LA          2021-10-31      293000
# MH          2021-10-31   122153000
# ML          2021-10-31     3224000
# MN          2021-10-31     3103000
# MP          2021-10-31    82232000
# MZ          2021-10-31     1192000
# NL          2021-10-31     2150000
# OR          2021-10-31    43671000
# PB          2021-10-31    29859000
# PY          2021-10-31     1504000
# RJ          2021-10-31    77264000
# SK          2021-10-31      664000
# TG          2021-10-31    37220000
# TN          2021-10-31    75695000
# TR          2021-10-31     3992000
# UP          2021-10-31   224979000
# UT          2021-10-31    11141000
# WB          2021-10-31    96906000

# %%
pd.DataFrame(data=[x for x in df["meta"]],index=df["meta"].keys()).drop(['last_updated','tested','vaccinated','notes'],axis=1).to_csv(r"C:\Users\Admin\Desktop\New_Project\csv\meta.csv")

# %% [markdown]
# # total

# %%
pd.DataFrame(data=[x for x in df["total"]],index=df["total"].keys())
# Out:
#             confirmed  deceased  recovered    tested  vaccinated1  \
# State_code
# AN               7651       129       7518    598033       294001
# AP            2066450     14373    2047722  29518787     32976969
# AR              55155       280      54774   1185436       771875
# AS             610645      5997     600974  24712042     20172463
# BR             726098      9661     716390  50531824     49874828
# CH              65351       820      64495    792851       926035
# CT            1006052     13577     992159  13709510     14851682
# DL            1439870     25091    1414431  29427753     13055636
# DN              10681         4      10644     72410       660753
# GA             178108      3364     174392   1468399      1262568
# GJ             826577     10089     816283  30928063     44735217
# HP             224106      3738     218410   3685011      5713695
# HR             771252     10049     761068  13032504     17772376
# JH             348764      5138     343518  15985878     14986646
# JK             332249      4432     326915  16202346      9511073
# KA            2988333     38082    2941578  50873103     42497761
# KL            4968657     31681    4857181  37886378     25306499
# LA              20962       208      20687    555568       208798
# MH            6611078    140216    6450585  62667211     67198794
# ML              83627      1450      81746   1151665      1103275
# MN             123731      1921     121102   1367673      1249436
# MP             792854     10524     782215  20294225     49911938
# MZ             121359       432     114612   1298444       711597
# NL              31842       685      29904    395416       709553
# OR            1041457      8386    1029147  21994343     25736641
# PB             602401     16559     585591  15429415     15942714
# PY             128013      1857     125726   1919060       733922
# RJ             954429      8954     945443  14807752     42544909
# SK              31979       396      31063    261343       521763
# TG             671463      3956     663498  27569831     22498559
# TN            2702623     36116    2655015  51159242     41279432
# TR              84468       813      83466   1983127      2508477
# UP            1710158     22900    1687151  83635222     98178865
# UT             343896      7400     330195   7781148      7478017
# WB            1592908     19141    1565471  19228303     56192166
#
#             vaccinated2   other
# State_code
# AN               200157     NaN
# AP             20375181     NaN
# AR               534486     NaN
# AS              8068795  1347.0
# BR             18346781     1.0
# CH               546981     NaN
# CT              7343273     NaN
# DL              7425404     NaN
# DN               370255    31.0
# GA               911114     NaN
# GJ             25972387     NaN
# HP              3443823    16.0
# HR              8115463     NaN
# JH              5585648     NaN
# JK              5149471     NaN
# KA             22858384    29.0
# KL             13658343   529.0
# LA               152280     NaN
# MH             30975692  3619.0
# ML               641819     NaN
# MN               719413     NaN
# MP             20838045     NaN
# MZ               512029     NaN
# NL               490663  1043.0
# OR             11560912     NaN
# PB              6238973     NaN
# PY               404355     NaN
# RJ             20097635     NaN
# SK               451509   325.0
# TG              9772398     NaN
# TN             17619141     NaN
# TR              1621329    63.0
# UP             32681895     NaN
# UT              3898342  6150.0
# WB             21559747     NaN

# %%
pd.DataFrame(data=[x for x in df["total"]],index=df["total"].keys()).isnull().sum()
# Out:
# confirmed       0
# deceased        0
# recovered       0
# tested          0
# vaccinated1     0
# vaccinated2     0
# other          24
# dtype: int64

# %% [markdown]
# # Total Table after data cleaning

# %%
pd.DataFrame(data=[x for x in df["total"]],index=df["total"].keys()).drop('other',axis=1)
# Out:
#             confirmed  deceased  recovered    tested  vaccinated1  vaccinated2
# State_code
# AN               7651       129       7518    598033       294001       200157
# AP            2066450     14373    2047722  29518787     32976969     20375181
# AR              55155       280      54774   1185436       771875       534486
# AS             610645      5997     600974  24712042     20172463      8068795
# BR             726098      9661     716390  50531824     49874828     18346781
# CH              65351       820      64495    792851       926035       546981
# CT            1006052     13577     992159  13709510     14851682      7343273
# DL            1439870     25091    1414431  29427753     13055636      7425404
# DN              10681         4      10644     72410       660753       370255
# GA             178108      3364     174392   1468399      1262568       911114
# GJ             826577     10089     816283  30928063     44735217     25972387
# HP             224106      3738     218410   3685011      5713695      3443823
# HR             771252     10049     761068  13032504     17772376      8115463
# JH             348764      5138     343518  15985878     14986646      5585648
# JK             332249      4432     326915  16202346      9511073      5149471
# KA            2988333     38082    2941578  50873103     42497761     22858384
# KL            4968657     31681    4857181  37886378     25306499     13658343
# LA              20962       208      20687    555568       208798       152280
# MH            6611078    140216    6450585  62667211     67198794     30975692
# ML              83627      1450      81746   1151665      1103275       641819
# MN             123731      1921     121102   1367673      1249436       719413
# MP             792854     10524     782215  20294225     49911938     20838045
# MZ             121359       432     114612   1298444       711597       512029
# NL              31842       685      29904    395416       709553       490663
# OR            1041457      8386    1029147  21994343     25736641     11560912
# PB             602401     16559     585591  15429415     15942714      6238973
# PY             128013      1857     125726   1919060       733922       404355
# RJ             954429      8954     945443  14807752     42544909     20097635
# SK              31979       396      31063    261343       521763       451509
# TG             671463      3956     663498  27569831     22498559      9772398
# TN            2702623     36116    2655015  51159242     41279432     17619141
# TR              84468       813      83466   1983127      2508477      1621329
# UP            1710158     22900    1687151  83635222     98178865     32681895
# UT             343896      7400     330195   7781148      7478017      3898342
# WB            1592908     19141    1565471  19228303     56192166     21559747

# %%
pd.DataFrame(data=[x for x in df["total"]],index=df["total"].keys()).drop('other',axis=1).to_csv(r"C:\Users\Admin\Desktop\New_Project\csv\total.csv")

# %% [markdown]
# # Districts

# %%
l1 =[]
l2 =[]
for i in df['districts']:
    for j in i:
        l1.append(j)
        l2.append(i[j])
df2 = pd.DataFrame([l1,l2])
df2 = df2.T
df2.rename( columns={0 :'districts'}, inplace=True )
df_districts=df2.set_index('districts')
df_districts
# Out:
#                                                                           1
# districts
# Nicobars                  {'delta7': {'vaccinated1': 62, 'vaccinated2': ...
# North and Middle Andaman  {'delta': {'vaccinated2': 8}, 'delta7': {'vacc...
# South Andaman             {'delta': {'vaccinated1': 3, 'vaccinated2': 28...
# Unknown                   {'delta21_14': {'confirmed': 9}, 'delta7': {'c...
# Anantapur                 {'delta': {'confirmed': 4, 'recovered': 5, 'va...
# ...                                                                     ...
# Purba Bardhaman           {'delta': {'confirmed': 16, 'recovered': 25, '...
# Purba Medinipur           {'delta': {'confirmed': 16, 'recovered': 17, '...
# Purulia                   {'delta': {'confirmed': 2, 'recovered': 3, 'va...
# South 24 Parganas         {'delta': {'confirmed': 75, 'deceased': 1, 're...
# Uttar Dinajpur            {'delta': {'confirmed': 8, 'recovered': 7}, 'd...
#
# [747 rows x 1 columns]

# %%
districts = pd.DataFrame([x for x in df_districts[1]],index=df_districts[1].keys())
districts
# Out:
#                                                                      delta7  \
# districts
# Nicobars                            {'vaccinated1': 62, 'vaccinated2': 811}
# North and Middle Andaman           {'vaccinated1': 90, 'vaccinated2': 1839}
# South Andaman                     {'vaccinated1': 732, 'vaccinated2': 8012}
# Unknown                                    {'confirmed': 3, 'recovered': 5}
# Anantapur                 {'confirmed': 38, 'recovered': 58, 'vaccinated...
# ...                                                                     ...
# Purba Bardhaman           {'confirmed': 147, 'deceased': 2, 'recovered':...
# Purba Medinipur           {'confirmed': 94, 'deceased': 1, 'recovered': ...
# Purulia                   {'confirmed': 17, 'recovered': 21, 'vaccinated...
# South 24 Parganas         {'confirmed': 542, 'deceased': 5, 'recovered':...
# Uttar Dinajpur            {'confirmed': 43, 'deceased': 2, 'recovered': ...
#
#                                                                        meta  \
# districts
# Nicobars                                              {'population': 36842}
# North and Middle Andaman                             {'population': 105597}
# South Andaman                                        {'population': 238142}
# Unknown                                                                 NaN
# Anantapur                 {'population': 4083315, 'tested': {'date': '20...
# ...                                                                     ...
# Purba Bardhaman                                     {'population': 4835532}
# Purba Medinipur                                     {'population': 4417377}
# Purulia                                             {'population': 2927965}
# South 24 Parganas                                   {'population': 8153176}
# Uttar Dinajpur                                      {'population': 3000849}
#
#                                                                       total  \
# districts
# Nicobars                       {'vaccinated1': 25394, 'vaccinated2': 20313}
# North and Middle Andaman       {'vaccinated1': 78945, 'vaccinated2': 59522}
# South Andaman                {'vaccinated1': 189662, 'vaccinated2': 120322}
# Unknown                   {'confirmed': 7651, 'deceased': 129, 'recovere...
# Anantapur                 {'confirmed': 157843, 'deceased': 1093, 'recov...
# ...                                                                     ...
# Purba Bardhaman           {'confirmed': 42005, 'deceased': 198, 'recover...
# Purba Medinipur           {'confirmed': 63098, 'deceased': 397, 'recover...
# Purulia                   {'confirmed': 19419, 'deceased': 113, 'recover...
# South 24 Parganas         {'confirmed': 100957, 'deceased': 1336, 'recov...
# Uttar Dinajpur            {'confirmed': 19858, 'deceased': 238, 'recover...
#
#                                                                       delta  \
# districts
# Nicobars                                                                NaN
# North and Middle Andaman                                 {'vaccinated2': 8}
# South Andaman                         {'vaccinated1': 3, 'vaccinated2': 28}
# Unknown                                                                 NaN
# Anantapur                 {'confirmed': 4, 'recovered': 5, 'vaccinated1'...
# ...                                                                     ...
# Purba Bardhaman           {'confirmed': 16, 'recovered': 25, 'vaccinated...
# Purba Medinipur           {'confirmed': 16, 'recovered': 17, 'vaccinated...
# Purulia                   {'confirmed': 2, 'recovered': 3, 'vaccinated1'...
# South 24 Parganas         {'confirmed': 75, 'deceased': 1, 'recovered': ...
# Uttar Dinajpur                             {'confirmed': 8, 'recovered': 7}
#
#                                   delta21_14
# districts
# Nicobars                                 NaN
# North and Middle Andaman                 NaN
# South Andaman                            NaN
# Unknown                     {'confirmed': 9}
# Anantapur                  {'confirmed': 50}
# ...                                      ...
# Purba Bardhaman           {'confirmed': 132}
# Purba Medinipur            {'confirmed': 65}
# Purulia                     {'confirmed': 9}
# South 24 Parganas         {'confirmed': 267}
# Uttar Dinajpur             {'confirmed': 25}
#
# [747 rows x 5 columns]

# %%
districts.isnull().sum()
# Out:
# delta7         14
# meta           31
# total           1
# delta          51
# delta21_14    321
# dtype: int64

# %%
districts.dropna(how='all',inplace=True)

# %%
districts.isnull().sum()
# Out:
# delta7         14
# meta           31
# total           1
# delta          51
# delta21_14    321
# dtype: int64

# %%
pd.DataFrame(districts['delta7'])
# Out:
#                                                                      delta7
# districts
# Nicobars                            {'vaccinated1': 62, 'vaccinated2': 811}
# North and Middle Andaman           {'vaccinated1': 90, 'vaccinated2': 1839}
# South Andaman                     {'vaccinated1': 732, 'vaccinated2': 8012}
# Unknown                                    {'confirmed': 3, 'recovered': 5}
# Anantapur                 {'confirmed': 38, 'recovered': 58, 'vaccinated...
# ...                                                                     ...
# Purba Bardhaman           {'confirmed': 147, 'deceased': 2, 'recovered':...
# Purba Medinipur           {'confirmed': 94, 'deceased': 1, 'recovered': ...
# Purulia                   {'confirmed': 17, 'recovered': 21, 'vaccinated...
# South 24 Parganas         {'confirmed': 542, 'deceased': 5, 'recovered':...
# Uttar Dinajpur            {'confirmed': 43, 'deceased': 2, 'recovered': ...
#
# [747 rows x 1 columns]

# %%
n1=districts.dropna(subset=['delta7'])
districts_delta7 = pd.DataFrame([x for x in n1['delta7']],index=[n1['delta7'].keys()])
districts_delta7
# Out:
#                           vaccinated1  vaccinated2  confirmed  recovered  \
# districts
# Nicobars                         62.0        811.0        NaN        NaN
# North and Middle Andaman         90.0       1839.0        NaN        NaN
# South Andaman                   732.0       8012.0        NaN        NaN
# Unknown                           NaN          NaN        3.0        5.0
# Anantapur                     92803.0     140903.0       38.0       58.0
# ...                               ...          ...        ...        ...
# Purba Bardhaman              260764.0      51741.0      147.0      176.0
# Purba Medinipur               71724.0     144185.0       94.0      120.0
# Purulia                      159111.0      40922.0       17.0       21.0
# South 24 Parganas            310444.0     169231.0      542.0      470.0
# Uttar Dinajpur               130243.0      44686.0       43.0       46.0
#
#                           deceased  tested  other
# districts
# Nicobars                       NaN     NaN    NaN
# North and Middle Andaman       NaN     NaN    NaN
# South Andaman                  NaN     NaN    NaN
# Unknown                        NaN     NaN    NaN
# Anantapur                      NaN     NaN    NaN
# ...                            ...     ...    ...
# Purba Bardhaman                2.0     NaN    NaN
# Purba Medinipur                1.0     NaN    NaN
# Purulia                        NaN     NaN    NaN
# South 24 Parganas              5.0     NaN    NaN
# Uttar Dinajpur                 2.0     NaN    NaN
#
# [733 rows x 7 columns]

# %%
districts_delta7.isnull().sum()
# Out:
# vaccinated1     15
# vaccinated2     15
# confirmed      314
# recovered      327
# deceased       586
# tested         731
# other          722
# dtype: int64

# %%
districts_delta7.dropna(how='all')
districts_delta7
# Out:
#                           vaccinated1  vaccinated2  confirmed  recovered  \
# districts
# Nicobars                         62.0        811.0        NaN        NaN
# North and Middle Andaman         90.0       1839.0        NaN        NaN
# South Andaman                   732.0       8012.0        NaN        NaN
# Unknown                           NaN          NaN        3.0        5.0
# Anantapur                     92803.0     140903.0       38.0       58.0
# ...                               ...          ...        ...        ...
# Purba Bardhaman              260764.0      51741.0      147.0      176.0
# Purba Medinipur               71724.0     144185.0       94.0      120.0
# Purulia                      159111.0      40922.0       17.0       21.0
# South 24 Parganas            310444.0     169231.0      542.0      470.0
# Uttar Dinajpur               130243.0      44686.0       43.0       46.0
#
#                           deceased  tested  other
# districts
# Nicobars                       NaN     NaN    NaN
# North and Middle Andaman       NaN     NaN    NaN
# South Andaman                  NaN     NaN    NaN
# Unknown                        NaN     NaN    NaN
# Anantapur                      NaN     NaN    NaN
# ...                            ...     ...    ...
# Purba Bardhaman                2.0     NaN    NaN
# Purba Medinipur                1.0     NaN    NaN
# Purulia                        NaN     NaN    NaN
# South 24 Parganas              5.0     NaN    NaN
# Uttar Dinajpur                 2.0     NaN    NaN
#
# [733 rows x 7 columns]

# %%
districts_delta7.isnull().sum()
# Out:
# vaccinated1     15
# vaccinated2     15
# confirmed      314
# recovered      327
# deceased       586
# tested         731
# other          722
# dtype: int64

# %% [markdown]
# # districts_delta7

# %%
districts_delta7.fillna(value=0,inplace=True)
districts_delta7
# Out:
#                           vaccinated1  vaccinated2  confirmed  recovered  \
# districts
# Nicobars                         62.0        811.0        0.0        0.0
# North and Middle Andaman         90.0       1839.0        0.0        0.0
# South Andaman                   732.0       8012.0        0.0        0.0
# Unknown                           0.0          0.0        3.0        5.0
# Anantapur                     92803.0     140903.0       38.0       58.0
# ...                               ...          ...        ...        ...
# Purba Bardhaman              260764.0      51741.0      147.0      176.0
# Purba Medinipur               71724.0     144185.0       94.0      120.0
# Purulia                      159111.0      40922.0       17.0       21.0
# South 24 Parganas            310444.0     169231.0      542.0      470.0
# Uttar Dinajpur               130243.0      44686.0       43.0       46.0
#
#                           deceased  tested  other
# districts
# Nicobars                       0.0     0.0    0.0
# North and Middle Andaman       0.0     0.0    0.0
# South Andaman                  0.0     0.0    0.0
# Unknown                        0.0     0.0    0.0
# Anantapur                      0.0     0.0    0.0
# ...                            ...     ...    ...
# Purba Bardhaman                2.0     0.0    0.0
# Purba Medinipur                1.0     0.0    0.0
# Purulia                        0.0     0.0    0.0
# South 24 Parganas              5.0     0.0    0.0
# Uttar Dinajpur                 2.0     0.0    0.0
#
# [733 rows x 7 columns]

# %%
districts_delta7.to_csv("C:/Users/Admin/Desktop/New_Project/csv/d_delta7.csv")

# %%
n2=districts.dropna(subset=['delta21_14'])
districts_delta21_14 = pd.DataFrame([x for x in n2['delta21_14']],index=[n2['delta21_14'].keys()])
districts_delta21_14
# Out:
#                    confirmed
# districts
# Unknown                    9
# Anantapur                 50
# Chittoor                 631
# East Godavari            401
# Guntur                   509
# ...                      ...
# Purba Bardhaman          132
# Purba Medinipur           65
# Purulia                    9
# South 24 Parganas        267
# Uttar Dinajpur            25
#
# [426 rows x 1 columns]

# %% [markdown]
# # districts_delta21_14

# %%
districts_delta21_14.fillna(value=0,inplace=True)
districts_delta21_14
# Out:
#                    confirmed
# districts
# Unknown                    9
# Anantapur                 50
# Chittoor                 631
# East Godavari            401
# Guntur                   509
# ...                      ...
# Purba Bardhaman          132
# Purba Medinipur           65
# Purulia                    9
# South 24 Parganas        267
# Uttar Dinajpur            25
#
# [426 rows x 1 columns]

# %%
districts_delta21_14.to_csv("C:/Users/Admin/Desktop/New_Project/csv/d_delta21_14.csv")

# %% [markdown]
# # districts_meta

# %%
n3=districts.dropna(subset=['meta'])
districts_meta = pd.DataFrame([x for x in n3['meta']],index=[n3['meta'].keys()])
districts_meta.drop(columns=["tested","vaccinated","notes"],axis=1,inplace=True)
districts_meta.fillna(value=0,inplace=True)
districts_meta
# Out:
#                           population
# districts
# Nicobars                     36842.0
# North and Middle Andaman    105597.0
# South Andaman               238142.0
# Anantapur                  4083315.0
# Chittoor                   4170468.0
# ...                              ...
# Purba Bardhaman            4835532.0
# Purba Medinipur            4417377.0
# Purulia                    2927965.0
# South 24 Parganas          8153176.0
# Uttar Dinajpur             3000849.0
#
# [716 rows x 1 columns]

# %%
districts_meta.to_csv(r"C:\Users\Admin\Desktop\New_Project\csv\d_meta.csv")

# %% [markdown]
# # districts_total

# %%
n4=districts.dropna(subset=['total'])
districts_total = pd.DataFrame([x for x in n4['total']],index=n4['total'].keys())
districts_total.drop(columns="other",inplace=True)
districts_total.fillna(value=0,inplace=True)
districts_total
# Out:
#                           vaccinated1  vaccinated2  confirmed  deceased  \
# districts
# Nicobars                      25394.0      20313.0        0.0       0.0
# North and Middle Andaman      78945.0      59522.0        0.0       0.0
# South Andaman                189662.0     120322.0        0.0       0.0
# Unknown                           0.0          0.0     7651.0     129.0
# Anantapur                   2690082.0    1611476.0   157843.0    1093.0
# ...                               ...          ...        ...       ...
# Purba Bardhaman             2596246.0     859528.0    42005.0     198.0
# Purba Medinipur             3560589.0    1471674.0    63098.0     397.0
# Purulia                     1679941.0     492310.0    19419.0     113.0
# South 24 Parganas           4850898.0    1832073.0   100957.0    1336.0
# Uttar Dinajpur              1341457.0     436182.0    19858.0     238.0
#
#                           recovered    tested
# districts
# Nicobars                        0.0       0.0
# North and Middle Andaman        0.0       0.0
# South Andaman                   0.0       0.0
# Unknown                      7518.0       0.0
# Anantapur                  156699.0  787085.0
# ...                             ...       ...
# Purba Bardhaman             41588.0       0.0
# Purba Medinipur             62549.0       0.0
# Purulia                     19283.0       0.0
# South 24 Parganas           98950.0       0.0
# Uttar Dinajpur              19559.0       0.0
#
# [746 rows x 6 columns]

# %%
districts_total.to_csv("C:/Users/Admin/Desktop/New_Project/csv/d_total.csv")

# %% [markdown]
# # districts_delta

# %%
n5=districts.dropna(subset=['delta'])
districts_delta = pd.DataFrame([x for x in n5['delta']],index=n5['delta'].keys())
districts_delta.drop(columns="other",inplace=True)
districts_delta.fillna(value=0,inplace=True)
districts_delta
# Out:
#                           vaccinated2  vaccinated1  confirmed  recovered  \
# districts
# North and Middle Andaman          8.0          0.0        0.0        0.0
# South Andaman                    28.0          3.0        0.0        0.0
# Anantapur                      5370.0       4575.0        4.0        5.0
# Chittoor                       1306.0        878.0       64.0       87.0
# East Godavari                   237.0         41.0       87.0      121.0
# ...                               ...          ...        ...        ...
# Purba Bardhaman                4002.0      17168.0       16.0       25.0
# Purba Medinipur                2226.0       5370.0       16.0       17.0
# Purulia                        1866.0      13266.0        2.0        3.0
# South 24 Parganas              3270.0       7086.0       75.0       74.0
# Uttar Dinajpur                    0.0          0.0        8.0        7.0
#
#                           deceased  tested
# districts
# North and Middle Andaman       0.0     0.0
# South Andaman                  0.0     0.0
# Anantapur                      0.0     0.0
# Chittoor                       1.0     0.0
# East Godavari                  0.0     0.0
# ...                            ...     ...
# Purba Bardhaman                0.0     0.0
# Purba Medinipur                0.0     0.0
# Purulia                        0.0     0.0
# South 24 Parganas              1.0     0.0
# Uttar Dinajpur                 0.0     0.0
#
# [696 rows x 6 columns]

# %%
districts_delta.to_csv(r"C:\Users\Admin\Desktop\New_Project\csv\d_delta.csv")
